# %%
import matplotlib.pyplot as plt
import numpy             as np
import pandas            as pd

def m(buffer):
    print(buffer)

# %%
# viusalize raw data
ad_dataset = pd.read_csv("./tvmarketing.csv")
ad_dataset.plot(x="TV",y="Sales",kind="scatter")
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Sales'>

# %%
# preparing x,y
x = ad_dataset["TV"]
y = ad_dataset["Sales"]

from sklearn.model_selection import train_test_split # to split data

x_train, x_test, y_train, y_test = \
        train_test_split(x, y, 
                    train_size=0.7, 
                    random_state=0000)

m(x_train.shape)
m(y_train.shape)

m(x_test.shape)
m(y_test.shape)


x_train = x_train[:, np.newaxis]
x_test = x_test[:, np.newaxis]
# Out:
# (140,)
# (140,)
# (60,)
# (60,)
# /tmp/ipykernel_2139/2358700751.py:19: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x_train = x_train[:, np.newaxis]
# /tmp/ipykernel_2139/2358700751.py:20: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x_test = x_test[:, np.newaxis]

# %%
from sklearn import linear_model

lin_reg = linear_model.LinearRegression()
lin_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
m(lin_reg.intercept_)
m(lin_reg.coef_)
y_pred = lin_reg.predict(x_test)
# Out:
# 7.310810165411681
# [0.04581434]

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred,c='blue')
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
plt.grid()

# %%
c = [i for i in range(1,61,1)]         # generating index 
fig = plt.figure()
plt.plot(c,y_test, color="blue", linewidth=2, linestyle="-")
plt.plot(c,y_pred, color="red",  linewidth=2, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20)              # Plot heading 
plt.xlabel('Index', fontsize=18)                               # X-label
plt.ylabel('Sales', fontsize=16)
# Out:
# Text(0, 0.5, 'Sales')

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
print(score)
# Out:
# 0.725606346597073
